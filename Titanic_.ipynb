# %%
import pandas as pd
import numpy as np
Titanic=pd.read_csv("/content/titanic.csv")
Titanic
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# 0     29.0000      0      0   24160  211.3375       B5        S         1
# 1      0.9167      1      2  113781  151.5500  C22 C26        S         1
# 2      2.0000      1      2  113781  151.5500  C22 C26        S         0
# 3     30.0000      1      2  113781  151.5500  C22 C26        S         0
# 4     25.0000      1      2  113781  151.5500  C22 C26        S         0
# ...       ...    ...    ...     ...       ...      ...      ...       ...
# 1304  14.5000      1      0    2665   14.4542      NaN        C         0
# 1305      NaN      1      0    2665   14.4542      NaN        C         0
# 1306  26.5000      0      0    2656    7.2250      NaN        C         0
# 1307  27.0000      0      0    2670    7.2250      NaN        C         0
# 1308  29.0000      0      0  315082    7.8750      NaN        S         0
#
# [1309 rows x 11 columns]

# %% [markdown]
# Understanding the Data set

# %%
Titanic.columns
# Out:
# Index(['pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'cabin', 'embarked', 'survived'],
#       dtype='object')

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
Titanic.describe()
# Out:
#             pclass          age        sibsp        parch         fare  \
# count  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000
# mean      2.294882    29.881135     0.498854     0.385027    33.295479
# std       0.837836    14.413500     1.041658     0.865560    51.758668
# min       1.000000     0.166700     0.000000     0.000000     0.000000
# 25%       2.000000    21.000000     0.000000     0.000000     7.895800
# 50%       3.000000    28.000000     0.000000     0.000000    14.454200
# 75%       3.000000    39.000000     1.000000     0.000000    31.275000
# max       3.000000    80.000000     8.000000     9.000000   512.329200
#
#           survived
# count  1309.000000
# mean      0.381971
# std       0.486055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
Titanic.describe(include='object')
# Out:
#                     name   sex    ticket        cabin embarked
# count               1309  1309      1309          295     1307
# unique              1307     2       929          186        3
# top     Kelly, Mr. James  male  CA. 2343  C23 C25 C27        S
# freq                   2   843        11            6      914

# %%
Titanic.head(n=5)
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0

# %%
Titanic.head(-10)
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1294       3                             Williams, Mr. Leslie    male
# 1295       3                              Windelov, Mr. Einar    male
# 1296       3                                 Wirz, Mr. Albert    male
# 1297       3                           Wiseman, Mr. Phillippe    male
# 1298       3                        Wittevrongel, Mr. Camille    male
#
#           age  sibsp  parch            ticket      fare    cabin embarked  \
# 0     29.0000      0      0             24160  211.3375       B5        S
# 1      0.9167      1      2            113781  151.5500  C22 C26        S
# 2      2.0000      1      2            113781  151.5500  C22 C26        S
# 3     30.0000      1      2            113781  151.5500  C22 C26        S
# 4     25.0000      1      2            113781  151.5500  C22 C26        S
# ...       ...    ...    ...               ...       ...      ...      ...
# 1294  28.5000      0      0             54636   16.1000      NaN        S
# 1295  21.0000      0      0  SOTON/OQ 3101317    7.2500      NaN        S
# 1296  27.0000      0      0            315154    8.6625      NaN        S
# 1297      NaN      0      0        A/4. 34244    7.2500      NaN        S
# 1298  36.0000      0      0            345771    9.5000      NaN        S
#
#       survived
# 0            1
# 1            1
# 2            0
# 3            0
# 4            0
# ...        ...
# 1294         0
# 1295         0
# 1296         0
# 1297         0
# 1298         0
#
# [1299 rows x 11 columns]

# %%
Titanic.tail(n=5)
# Out:
#       pclass                       name     sex   age  sibsp  parch  ticket  \
# 1304       3       Zabour, Miss. Hileni  female  14.5      1      0    2665
# 1305       3      Zabour, Miss. Thamine  female   NaN      1      0    2665
# 1306       3  Zakarian, Mr. Mapriededer    male  26.5      0      0    2656
# 1307       3        Zakarian, Mr. Ortin    male  27.0      0      0    2670
# 1308       3         Zimmerman, Mr. Leo    male  29.0      0      0  315082
#
#          fare cabin embarked  survived
# 1304  14.4542   NaN        C         0
# 1305  14.4542   NaN        C         0
# 1306   7.2250   NaN        C         0
# 1307   7.2250   NaN        C         0
# 1308   7.8750   NaN        S         0

# %%
Titanic.loc[1,'name']
# Out:
# 'Allison, Master. Hudson Trevor'

# %%
Titanic.loc[0,'age']
# Out:
# np.float64(29.0)

# %%
Titanic.loc[[1,2,3],["name","age","parch"]]
# Out:
#                                    name      age  parch
# 1        Allison, Master. Hudson Trevor   0.9167      2
# 2          Allison, Miss. Helen Loraine   2.0000      2
# 3  Allison, Mr. Hudson Joshua Creighton  30.0000      2

# %%
Titanic.loc[5]
# Out:
# pclass                        1
# name        Anderson, Mr. Harry
# sex                        male
# age                        48.0
# sibsp                         0
# parch                         0
# ticket                    19952
# fare                      26.55
# cabin                       E12
# embarked                      S
# survived                      1
# Name: 5, dtype: object

# %%
Titanic.iloc[2,2]
# Out:
# 'female'

# %%
Titanic.iloc[2,5]
# Out:
# np.int64(2)

# %%
Titanic.iloc[::2,1]
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 2                          Allison, Miss. Helen Loraine
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6                     Andrews, Miss. Kornelia Theodosia
# 8         Appleton, Mrs. Edward Dale (Charlotte Lamson)
#                              ...
# 1300            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1302                                  Yousif, Mr. Wazli
# 1304                               Zabour, Miss. Hileni
# 1306                          Zakarian, Mr. Mapriededer
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 655, dtype: object

# %%
Titanic.iloc[::1,2]
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
Titanic.iloc[::2,:3:1]
# Out:
#       pclass                                             name     sex
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 2          1                     Allison, Miss. Helen Loraine  female
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 6          1                Andrews, Miss. Kornelia Theodosia  female
# 8          1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# ...      ...                                              ...     ...
# 1300       3          Yasbeck, Mrs. Antoni (Selini Alexander)  female
# 1302       3                                Yousif, Mr. Wazli    male
# 1304       3                             Zabour, Miss. Hileni  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
# [655 rows x 3 columns]

# %% [markdown]
# Data Cleaning

# %%
Titanic.isnull()
# Out:
#       pclass   name    sex    age  sibsp  parch  ticket   fare  cabin  \
# 0      False  False  False  False  False  False   False  False  False
# 1      False  False  False  False  False  False   False  False  False
# 2      False  False  False  False  False  False   False  False  False
# 3      False  False  False  False  False  False   False  False  False
# 4      False  False  False  False  False  False   False  False  False
# ...      ...    ...    ...    ...    ...    ...     ...    ...    ...
# 1304   False  False  False  False  False  False   False  False   True
# 1305   False  False  False   True  False  False   False  False   True
# 1306   False  False  False  False  False  False   False  False   True
# 1307   False  False  False  False  False  False   False  False   True
# 1308   False  False  False  False  False  False   False  False   True
#
#       embarked  survived
# 0        False     False
# 1        False     False
# 2        False     False
# 3        False     False
# 4        False     False
# ...        ...       ...
# 1304     False     False
# 1305     False     False
# 1306     False     False
# 1307     False     False
# 1308     False     False
#
# [1309 rows x 11 columns]

# %%
Titanic.isnull().sum().isnull()
# Out:
# pclass      False
# name        False
# sex         False
# age         False
# sibsp       False
# parch       False
# ticket      False
# fare        False
# cabin       False
# embarked    False
# survived    False
# dtype: bool

# %%
null_counts = Titanic.isnull().sum().sum()
print(null_counts)
# Out:
# 1280

# %%
Titanic['cabin'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304     True
# 1305     True
# 1306     True
# 1307     True
# 1308     True
# Name: cabin, Length: 1309, dtype: bool

# %%
Titanic[Titanic['cabin'].isnull()]
# Out:
#       pclass                          name     sex   age  sibsp  parch  \
# 9          1       Artagaveytia, Mr. Ramon    male  71.0      0      0
# 13         1  Barber, Miss. Ellen "Nellie"  female  26.0      0      0
# 15         1           Baumann, Mr. John D    male   NaN      0      0
# 23         1         Bidois, Miss. Rosalie  female  42.0      0      0
# 25         1           Birnbaum, Mr. Jakob    male  25.0      0      0
# ...      ...                           ...     ...   ...    ...    ...
# 1304       3          Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3     Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3           Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3            Zimmerman, Mr. Leo    male  29.0      0      0
#
#         ticket      fare cabin embarked  survived
# 9     PC 17609   49.5042   NaN        C         0
# 13       19877   78.8500   NaN        S         1
# 15    PC 17318   25.9250   NaN        S         0
# 23    PC 17757  227.5250   NaN        C         1
# 25       13905   26.0000   NaN        C         0
# ...        ...       ...   ...      ...       ...
# 1304      2665   14.4542   NaN        C         0
# 1305      2665   14.4542   NaN        C         0
# 1306      2656    7.2250   NaN        C         0
# 1307      2670    7.2250   NaN        C         0
# 1308    315082    7.8750   NaN        S         0
#
# [1014 rows x 11 columns]

# %%
Titanic['cabin'].notnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: cabin, Length: 1309, dtype: bool

# %%
Titanic[Titanic['cabin'].notnull()]
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1189       3                  Sandstrom, Miss. Marguerite Rut  female
# 1217       3       Soholt, Mr. Peter Andreas Lauritz Andersen    male
# 1230       3                       Strom, Miss. Telma Matilda  female
# 1231       3       Strom, Mrs. Wilhelm (Elna Matilda Persson)  female
# 1249       3                                 Tobin, Mr. Roger    male
#
#           age  sibsp  parch   ticket      fare    cabin embarked  survived
# 0     29.0000      0      0    24160  211.3375       B5        S         1
# 1      0.9167      1      2   113781  151.5500  C22 C26        S         1
# 2      2.0000      1      2   113781  151.5500  C22 C26        S         0
# 3     30.0000      1      2   113781  151.5500  C22 C26        S         0
# 4     25.0000      1      2   113781  151.5500  C22 C26        S         0
# ...       ...    ...    ...      ...       ...      ...      ...       ...
# 1189   4.0000      1      1  PP 9549   16.7000       G6        S         1
# 1217  19.0000      0      0   348124    7.6500    F G73        S         0
# 1230   2.0000      0      1   347054   10.4625       G6        S         0
# 1231  29.0000      1      1   347054   10.4625       G6        S         0
# 1249      NaN      0      0   383121    7.7500      F38        Q         0
#
# [295 rows x 11 columns]

# %%
Titanic.describe()
# Out:
#             pclass          age        sibsp        parch         fare  \
# count  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000
# mean      2.294882    29.881135     0.498854     0.385027    33.295479
# std       0.837836    14.413500     1.041658     0.865560    51.758668
# min       1.000000     0.166700     0.000000     0.000000     0.000000
# 25%       2.000000    21.000000     0.000000     0.000000     7.895800
# 50%       3.000000    28.000000     0.000000     0.000000    14.454200
# 75%       3.000000    39.000000     1.000000     0.000000    31.275000
# max       3.000000    80.000000     8.000000     9.000000   512.329200
#
#           survived
# count  1309.000000
# mean      0.381971
# std       0.486055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
Titanic.isnull().sum()
# Out:
# pclass         0
# name           0
# sex            0
# age          263
# sibsp          0
# parch          0
# ticket         0
# fare           1
# cabin       1014
# embarked       2
# survived       0
# dtype: int64

# %% [markdown]
# To handle null values using **fillna** functions

# %%
Titanic["fare"]
c=0
for i in Titanic["fare"]:
  if pd.isnull(i):
    break
  c+=1
print(c)
# Out:
# 1225

# %%
Titanic.loc[1225,'fare']
# Out:
# np.float64(nan)

# %%
Titanic['fare'].mean()
# Out:
# np.float64(33.29547928134557)

# %%
fare_mean=Titanic['fare'].mean()
fare_mean
# Out:
# np.float64(33.29547928134557)

# %%
Titanic['fare'].fillna(fare_mean,inplace=True)
# Out:
# <ipython-input-33-3e8d36538d73>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Titanic['fare'].fillna(fare_mean,inplace=True)

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1309 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
Titanic['fare']=Titanic['fare'].fillna(fare_mean)
Titanic['fare'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: fare, Length: 1309, dtype: bool

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1309 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
Titanic.isnull().sum()
# Out:
# pclass         0
# name           0
# sex            0
# age          263
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin       1014
# embarked       2
# survived       0
# dtype: int64

# %%
Titanic['age'].mean()
age_mean=Titanic['age'].mean()
age_mean
# Out:
# np.float64(29.8811345124283)

# %%
Titanic['age'].fillna(age_mean,inplace=True)
Titanic
# Out:
# <ipython-input-39-2fc77febf84b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Titanic['age'].fillna(age_mean,inplace=True)
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#             age  sibsp  parch  ticket      fare    cabin embarked  survived
# 0     29.000000      0      0   24160  211.3375       B5        S         1
# 1      0.916700      1      2  113781  151.5500  C22 C26        S         1
# 2      2.000000      1      2  113781  151.5500  C22 C26        S         0
# 3     30.000000      1      2  113781  151.5500  C22 C26        S         0
# 4     25.000000      1      2  113781  151.5500  C22 C26        S         0
# ...         ...    ...    ...     ...       ...      ...      ...       ...
# 1304  14.500000      1      0    2665   14.4542      NaN        C         0
# 1305  29.881135      1      0    2665   14.4542      NaN        C         0
# 1306  26.500000      0      0    2656    7.2250      NaN        C         0
# 1307  27.000000      0      0    2670    7.2250      NaN        C         0
# 1308  29.000000      0      0  315082    7.8750      NaN        S         0
#
# [1309 rows x 11 columns]

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1309 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1309 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
Titanic.isnull().sum()
# Out:
# pclass         0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin       1014
# embarked       2
# survived       0
# dtype: int64

# %%
Titanic['embarked'].isnull().sum()
# Out:
# np.int64(2)

# %%
c=0
for i in Titanic['embarked']:
  if pd.isnull(i):
    print(c)
  c+=1
# Out:
# 168
# 284

# %%
Titanic['embarked'].mode()
# Out:
# 0    S
# Name: embarked, dtype: object

# %%
Titanic['embarked'].mode()[0]
embarked_mode=Titanic['embarked'].mode()[0]

# %%
Titanic['embarked'].fillna(embarked_mode,inplace=True)
Titanic
# Out:
# <ipython-input-46-5b2c256e8793>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Titanic['embarked'].fillna(embarked_mode,inplace=True)
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#             age  sibsp  parch  ticket      fare    cabin embarked  survived
# 0     29.000000      0      0   24160  211.3375       B5        S         1
# 1      0.916700      1      2  113781  151.5500  C22 C26        S         1
# 2      2.000000      1      2  113781  151.5500  C22 C26        S         0
# 3     30.000000      1      2  113781  151.5500  C22 C26        S         0
# 4     25.000000      1      2  113781  151.5500  C22 C26        S         0
# ...         ...    ...    ...     ...       ...      ...      ...       ...
# 1304  14.500000      1      0    2665   14.4542      NaN        C         0
# 1305  29.881135      1      0    2665   14.4542      NaN        C         0
# 1306  26.500000      0      0    2656    7.2250      NaN        C         0
# 1307  27.000000      0      0    2670    7.2250      NaN        C         0
# 1308  29.000000      0      0  315082    7.8750      NaN        S         0
#
# [1309 rows x 11 columns]

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1309 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1309 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1309 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
Titanic.dropna(axis=1,inplace=True)
Titanic
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#             age  sibsp  parch  ticket      fare embarked  survived
# 0     29.000000      0      0   24160  211.3375        S         1
# 1      0.916700      1      2  113781  151.5500        S         1
# 2      2.000000      1      2  113781  151.5500        S         0
# 3     30.000000      1      2  113781  151.5500        S         0
# 4     25.000000      1      2  113781  151.5500        S         0
# ...         ...    ...    ...     ...       ...      ...       ...
# 1304  14.500000      1      0    2665   14.4542        C         0
# 1305  29.881135      1      0    2665   14.4542        C         0
# 1306  26.500000      0      0    2656    7.2250        C         0
# 1307  27.000000      0      0    2670    7.2250        C         0
# 1308  29.000000      0      0  315082    7.8750        S         0
#
# [1309 rows x 10 columns]

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1309 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1309 non-null   float64
#  8   embarked  1309 non-null   object
#  9   survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 102.4+ KB

# %%
Titanic.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
Titanic.astype({'age':int})
# Out:
#       pclass                                             name     sex  age  \
# 0          1                    Allen, Miss. Elisabeth Walton  female   29
# 1          1                   Allison, Master. Hudson Trevor    male    0
# 2          1                     Allison, Miss. Helen Loraine  female    2
# 3          1             Allison, Mr. Hudson Joshua Creighton    male   30
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female   25
# ...      ...                                              ...     ...  ...
# 1304       3                             Zabour, Miss. Hileni  female   14
# 1305       3                            Zabour, Miss. Thamine  female   29
# 1306       3                        Zakarian, Mr. Mapriededer    male   26
# 1307       3                              Zakarian, Mr. Ortin    male   27
# 1308       3                               Zimmerman, Mr. Leo    male   29
#
#       sibsp  parch  ticket      fare embarked  survived
# 0         0      0   24160  211.3375        S         1
# 1         1      2  113781  151.5500        S         1
# 2         1      2  113781  151.5500        S         0
# 3         1      2  113781  151.5500        S         0
# 4         1      2  113781  151.5500        S         0
# ...     ...    ...     ...       ...      ...       ...
# 1304      1      0    2665   14.4542        C         0
# 1305      1      0    2665   14.4542        C         0
# 1306      0      0    2656    7.2250        C         0
# 1307      0      0    2670    7.2250        C         0
# 1308      0      0  315082    7.8750        S         0
#
# [1309 rows x 10 columns]

# %%
Titanic['fare']=Titanic['fare'].astype(int)

# %%
Titanic
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#             age  sibsp  parch  ticket  fare embarked  survived
# 0     29.000000      0      0   24160   211        S         1
# 1      0.916700      1      2  113781   151        S         1
# 2      2.000000      1      2  113781   151        S         0
# 3     30.000000      1      2  113781   151        S         0
# 4     25.000000      1      2  113781   151        S         0
# ...         ...    ...    ...     ...   ...      ...       ...
# 1304  14.500000      1      0    2665    14        C         0
# 1305  29.881135      1      0    2665    14        C         0
# 1306  26.500000      0      0    2656     7        C         0
# 1307  27.000000      0      0    2670     7        C         0
# 1308  29.000000      0      0  315082     7        S         0
#
# [1309 rows x 10 columns]

# %% [markdown]
# Data Manipulation or transformation
# 1.set_index()
# 2.reset_index()
# 3.rename()
# 4.replace()
# 5.map()
# 6.merge()
# 7.concat()
# 8.drop()
# 9.explode()
# 10.melt()
# 11.cut()

# %%
df=pd.DataFrame({'empno':['e1','e2','e3','e4'],
                 'ename':['smith','allen','ward','ford'],
                 'sal':[1000,3000,400,2000],
                 'comm':[200,None,500,None]})

# %%
df
# Out:
#   empno  ename   sal   comm
# 0    e1  smith  1000  200.0
# 1    e2  allen  3000    NaN
# 2    e3   ward   400  500.0
# 3    e4   ford  2000    NaN

# %%
df['comm']
# Out:
# 0    200.0
# 1      NaN
# 2    500.0
# 3      NaN
# Name: comm, dtype: float64

# %%
df['comm'].mean()
df_mean=df['comm'].mean()

# %%
df['comm'].fillna(df_mean,inplace=True)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   empno   4 non-null      object
#  1   ename   4 non-null      object
#  2   sal     4 non-null      int64
#  3   comm    4 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 260.0+ bytes
#   empno  ename   sal   comm
# 0    e1  smith  1000  200.0
# 1    e2  allen  3000  350.0
# 2    e3   ward   400  500.0
# 3    e4   ford  2000  350.0

# %%
df.reset_index(drop=False)
df
# Out:
#   empno  ename   sal   comm
# 0    e1  smith  1000  200.0
# 1    e2  allen  3000  350.0
# 2    e3   ward   400  500.0
# 3    e4   ford  2000  350.0

# %%
df.rename(columns={'empno':'emp_no'},inplace=True)
df
# Out:
#   emp_no  ename   sal   comm
# 0     e1  smith  1000  200.0
# 1     e2  allen  3000  350.0
# 2     e3   ward   400  500.0
# 3     e4   ford  2000  350.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   emp_no  4 non-null      object
#  1   ename   4 non-null      object
#  2   sal     4 non-null      int64
#  3   comm    4 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 260.0+ bytes

# %%
df
# Out:
#   emp_no  ename   sal   comm
# 0     e1  smith  1000  200.0
# 1     e2  allen  3000  350.0
# 2     e3   ward   400  500.0
# 3     e4   ford  2000  350.0

# %%
df.replace({1000:1200})
# Out:
#   emp_no  ename   sal   comm
# 0     e1  smith  1200  200.0
# 1     e2  allen  3000  350.0
# 2     e3   ward   400  500.0
# 3     e4   ford  2000  350.0

# %%
df.drop('comm',axis=1,inplace=False)
df
# Out:
#   emp_no  ename   sal   comm
# 0     e1  smith  1000  200.0
# 1     e2  allen  3000  350.0
# 2     e3   ward   400  500.0
# 3     e4   ford  2000  350.0

# %%
Titanic
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#             age  sibsp  parch  ticket  fare embarked  survived
# 0     29.000000      0      0   24160   211        S         1
# 1      0.916700      1      2  113781   151        S         1
# 2      2.000000      1      2  113781   151        S         0
# 3     30.000000      1      2  113781   151        S         0
# 4     25.000000      1      2  113781   151        S         0
# ...         ...    ...    ...     ...   ...      ...       ...
# 1304  14.500000      1      0    2665    14        C         0
# 1305  29.881135      1      0    2665    14        C         0
# 1306  26.500000      0      0    2656     7        C         0
# 1307  27.000000      0      0    2670     7        C         0
# 1308  29.000000      0      0  315082     7        S         0
#
# [1309 rows x 10 columns]

# %%
# Titanic['age']=Titanic['age'].fillna(0).astype(int)
# Titanic

# %%
Titanic.rename(columns={'sex':'gender'},inplace=True)
Titanic
# Out:
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#             age  sibsp  parch  ticket  fare embarked  survived
# 0     29.000000      0      0   24160   211        S         1
# 1      0.916700      1      2  113781   151        S         1
# 2      2.000000      1      2  113781   151        S         0
# 3     30.000000      1      2  113781   151        S         0
# 4     25.000000      1      2  113781   151        S         0
# ...         ...    ...    ...     ...   ...      ...       ...
# 1304  14.500000      1      0    2665    14        C         0
# 1305  29.881135      1      0    2665    14        C         0
# 1306  26.500000      0      0    2656     7        C         0
# 1307  27.000000      0      0    2670     7        C         0
# 1308  29.000000      0      0  315082     7        S         0
#
# [1309 rows x 10 columns]

# %%
Titanic['gender']=Titanic['gender'].replace({'male':1,'female':0})
Titanic
# Out:
# <ipython-input-68-6fe9e254d9c9>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Titanic['gender']=Titanic['gender'].replace({'male':1,'female':0})
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton       0
# 1          1                   Allison, Master. Hudson Trevor       1
# 2          1                     Allison, Miss. Helen Loraine       0
# 3          1             Allison, Mr. Hudson Joshua Creighton       1
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       0
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni       0
# 1305       3                            Zabour, Miss. Thamine       0
# 1306       3                        Zakarian, Mr. Mapriededer       1
# 1307       3                              Zakarian, Mr. Ortin       1
# 1308       3                               Zimmerman, Mr. Leo       1
#
#             age  sibsp  parch  ticket  fare embarked  survived
# 0     29.000000      0      0   24160   211        S         1
# 1      0.916700      1      2  113781   151        S         1
# 2      2.000000      1      2  113781   151        S         0
# 3     30.000000      1      2  113781   151        S         0
# 4     25.000000      1      2  113781   151        S         0
# ...         ...    ...    ...     ...   ...      ...       ...
# 1304  14.500000      1      0    2665    14        C         0
# 1305  29.881135      1      0    2665    14        C         0
# 1306  26.500000      0      0    2656     7        C         0
# 1307  27.000000      0      0    2670     7        C         0
# 1308  29.000000      0      0  315082     7        S         0
#
# [1309 rows x 10 columns]

# %%
Titanic['embarked']=Titanic['embarked'].replace({'S':'southampton','C':'cherbourg','Q':'qeenstown'})
Titanic
# Out:
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton       0
# 1          1                   Allison, Master. Hudson Trevor       1
# 2          1                     Allison, Miss. Helen Loraine       0
# 3          1             Allison, Mr. Hudson Joshua Creighton       1
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       0
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni       0
# 1305       3                            Zabour, Miss. Thamine       0
# 1306       3                        Zakarian, Mr. Mapriededer       1
# 1307       3                              Zakarian, Mr. Ortin       1
# 1308       3                               Zimmerman, Mr. Leo       1
#
#             age  sibsp  parch  ticket  fare     embarked  survived
# 0     29.000000      0      0   24160   211  southampton         1
# 1      0.916700      1      2  113781   151  southampton         1
# 2      2.000000      1      2  113781   151  southampton         0
# 3     30.000000      1      2  113781   151  southampton         0
# 4     25.000000      1      2  113781   151  southampton         0
# ...         ...    ...    ...     ...   ...          ...       ...
# 1304  14.500000      1      0    2665    14    cherbourg         0
# 1305  29.881135      1      0    2665    14    cherbourg         0
# 1306  26.500000      0      0    2656     7    cherbourg         0
# 1307  27.000000      0      0    2670     7    cherbourg         0
# 1308  29.000000      0      0  315082     7  southampton         0
#
# [1309 rows x 10 columns]

# %% [markdown]
# Feature Engineering

# %%
Titanic['Family_count']=Titanic['sibsp']+Titanic['parch']
Titanic
# Out:
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton       0
# 1          1                   Allison, Master. Hudson Trevor       1
# 2          1                     Allison, Miss. Helen Loraine       0
# 3          1             Allison, Mr. Hudson Joshua Creighton       1
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       0
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni       0
# 1305       3                            Zabour, Miss. Thamine       0
# 1306       3                        Zakarian, Mr. Mapriededer       1
# 1307       3                              Zakarian, Mr. Ortin       1
# 1308       3                               Zimmerman, Mr. Leo       1
#
#             age  sibsp  parch  ticket  fare     embarked  survived  \
# 0     29.000000      0      0   24160   211  southampton         1
# 1      0.916700      1      2  113781   151  southampton         1
# 2      2.000000      1      2  113781   151  southampton         0
# 3     30.000000      1      2  113781   151  southampton         0
# 4     25.000000      1      2  113781   151  southampton         0
# ...         ...    ...    ...     ...   ...          ...       ...
# 1304  14.500000      1      0    2665    14    cherbourg         0
# 1305  29.881135      1      0    2665    14    cherbourg         0
# 1306  26.500000      0      0    2656     7    cherbourg         0
# 1307  27.000000      0      0    2670     7    cherbourg         0
# 1308  29.000000      0      0  315082     7  southampton         0
#
#       Family_count
# 0                0
# 1                3
# 2                3
# 3                3
# 4                3
# ...            ...
# 1304             1
# 1305             1
# 1306             0
# 1307             0
# 1308             0
#
# [1309 rows x 11 columns]

# %%
Titanic.drop(columns=['sibsp','parch'],inplace=True)
Titanic
# Out:
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton       0
# 1          1                   Allison, Master. Hudson Trevor       1
# 2          1                     Allison, Miss. Helen Loraine       0
# 3          1             Allison, Mr. Hudson Joshua Creighton       1
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       0
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni       0
# 1305       3                            Zabour, Miss. Thamine       0
# 1306       3                        Zakarian, Mr. Mapriededer       1
# 1307       3                              Zakarian, Mr. Ortin       1
# 1308       3                               Zimmerman, Mr. Leo       1
#
#             age  ticket  fare     embarked  survived  Family_count
# 0     29.000000   24160   211  southampton         1             0
# 1      0.916700  113781   151  southampton         1             3
# 2      2.000000  113781   151  southampton         0             3
# 3     30.000000  113781   151  southampton         0             3
# 4     25.000000  113781   151  southampton         0             3
# ...         ...     ...   ...          ...       ...           ...
# 1304  14.500000    2665    14    cherbourg         0             1
# 1305  29.881135    2665    14    cherbourg         0             1
# 1306  26.500000    2656     7    cherbourg         0             0
# 1307  27.000000    2670     7    cherbourg         0             0
# 1308  29.000000  315082     7  southampton         0             0
#
# [1309 rows x 9 columns]

# %% [markdown]
# Converting name (object-----> string) and split it

# %%
Titanic['name'].str.split(',',expand=True) #if expand=False it gives o/p in form of list                                            #if expand=True then, each element of list will be separate columns
# Out:
#               0                                        1
# 0         Allen                   Miss. Elisabeth Walton
# 1       Allison                    Master. Hudson Trevor
# 2       Allison                      Miss. Helen Loraine
# 3       Allison              Mr. Hudson Joshua Creighton
# 4       Allison   Mrs. Hudson J C (Bessie Waldo Daniels)
# ...         ...                                      ...
# 1304     Zabour                             Miss. Hileni
# 1305     Zabour                            Miss. Thamine
# 1306   Zakarian                          Mr. Mapriededer
# 1307   Zakarian                                Mr. Ortin
# 1308  Zimmerman                                  Mr. Leo
#
# [1309 rows x 2 columns]

# %%
Titanic['last_name']=Titanic['name'].str.split(',',expand=True)[0]

# %%
title_fname=Titanic['name'].str.split(',',expand=True)[1]
Titanic['title']=title_fname.str.split('.',n=1,expand=True)[0]
Titanic['first_name']=title_fname.str.split('.',n=1,expand=True)[1]
Titanic
# Out:
#       pclass                                             name  gender  \
# 0          1                    Allen, Miss. Elisabeth Walton       0
# 1          1                   Allison, Master. Hudson Trevor       1
# 2          1                     Allison, Miss. Helen Loraine       0
# 3          1             Allison, Mr. Hudson Joshua Creighton       1
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       0
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni       0
# 1305       3                            Zabour, Miss. Thamine       0
# 1306       3                        Zakarian, Mr. Mapriededer       1
# 1307       3                              Zakarian, Mr. Ortin       1
# 1308       3                               Zimmerman, Mr. Leo       1
#
#             age  ticket  fare     embarked  survived  Family_count  last_name  \
# 0     29.000000   24160   211  southampton         1             0      Allen
# 1      0.916700  113781   151  southampton         1             3    Allison
# 2      2.000000  113781   151  southampton         0             3    Allison
# 3     30.000000  113781   151  southampton         0             3    Allison
# 4     25.000000  113781   151  southampton         0             3    Allison
# ...         ...     ...   ...          ...       ...           ...        ...
# 1304  14.500000    2665    14    cherbourg         0             1     Zabour
# 1305  29.881135    2665    14    cherbourg         0             1     Zabour
# 1306  26.500000    2656     7    cherbourg         0             0   Zakarian
# 1307  27.000000    2670     7    cherbourg         0             0   Zakarian
# 1308  29.000000  315082     7  southampton         0             0  Zimmerman
#
#         title                          first_name
# 0        Miss                    Elisabeth Walton
# 1      Master                       Hudson Trevor
# 2        Miss                       Helen Loraine
# 3          Mr             Hudson Joshua Creighton
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)
# ...       ...                                 ...
# 1304     Miss                              Hileni
# 1305     Miss                             Thamine
# 1306       Mr                         Mapriededer
# 1307       Mr                               Ortin
# 1308       Mr                                 Leo
#
# [1309 rows x 12 columns]

# %%
Titanic.drop(columns=['name'],inplace=True)
Titanic
# Out:
#       pclass  gender        age  ticket  fare     embarked  survived  \
# 0          1       0  29.000000   24160   211  southampton         1
# 1          1       1   0.916700  113781   151  southampton         1
# 2          1       0   2.000000  113781   151  southampton         0
# 3          1       1  30.000000  113781   151  southampton         0
# 4          1       0  25.000000  113781   151  southampton         0
# ...      ...     ...        ...     ...   ...          ...       ...
# 1304       3       0  14.500000    2665    14    cherbourg         0
# 1305       3       0  29.881135    2665    14    cherbourg         0
# 1306       3       1  26.500000    2656     7    cherbourg         0
# 1307       3       1  27.000000    2670     7    cherbourg         0
# 1308       3       1  29.000000  315082     7  southampton         0
#
#       Family_count  last_name    title                          first_name
# 0                0      Allen     Miss                    Elisabeth Walton
# 1                3    Allison   Master                       Hudson Trevor
# 2                3    Allison     Miss                       Helen Loraine
# 3                3    Allison       Mr             Hudson Joshua Creighton
# 4                3    Allison      Mrs   Hudson J C (Bessie Waldo Daniels)
# ...            ...        ...      ...                                 ...
# 1304             1     Zabour     Miss                              Hileni
# 1305             1     Zabour     Miss                             Thamine
# 1306             0   Zakarian       Mr                         Mapriededer
# 1307             0   Zakarian       Mr                               Ortin
# 1308             0  Zimmerman       Mr                                 Leo
#
# [1309 rows x 11 columns]

# %%
columns=['title','first_name','last_name','gender','age','Family_count','ticket','pclass','fare','embarked','survived']
Titanic=Titanic[columns]
Titanic
# Out:
#         title                          first_name  last_name  gender  \
# 0        Miss                    Elisabeth Walton      Allen       0
# 1      Master                       Hudson Trevor    Allison       1
# 2        Miss                       Helen Loraine    Allison       0
# 3          Mr             Hudson Joshua Creighton    Allison       1
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)    Allison       0
# ...       ...                                 ...        ...     ...
# 1304     Miss                              Hileni     Zabour       0
# 1305     Miss                             Thamine     Zabour       0
# 1306       Mr                         Mapriededer   Zakarian       1
# 1307       Mr                               Ortin   Zakarian       1
# 1308       Mr                                 Leo  Zimmerman       1
#
#             age  Family_count  ticket  pclass  fare     embarked  survived
# 0     29.000000             0   24160       1   211  southampton         1
# 1      0.916700             3  113781       1   151  southampton         1
# 2      2.000000             3  113781       1   151  southampton         0
# 3     30.000000             3  113781       1   151  southampton         0
# 4     25.000000             3  113781       1   151  southampton         0
# ...         ...           ...     ...     ...   ...          ...       ...
# 1304  14.500000             1    2665       3    14    cherbourg         0
# 1305  29.881135             1    2665       3    14    cherbourg         0
# 1306  26.500000             0    2656       3     7    cherbourg         0
# 1307  27.000000             0    2670       3     7    cherbourg         0
# 1308  29.000000             0  315082       3     7  southampton         0
#
# [1309 rows x 11 columns]

# %%
Titanic.sort_values(by=['first_name'])
Titanic
# Out:
#         title                          first_name  last_name  gender  \
# 0        Miss                    Elisabeth Walton      Allen       0
# 1      Master                       Hudson Trevor    Allison       1
# 2        Miss                       Helen Loraine    Allison       0
# 3          Mr             Hudson Joshua Creighton    Allison       1
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)    Allison       0
# ...       ...                                 ...        ...     ...
# 1304     Miss                              Hileni     Zabour       0
# 1305     Miss                             Thamine     Zabour       0
# 1306       Mr                         Mapriededer   Zakarian       1
# 1307       Mr                               Ortin   Zakarian       1
# 1308       Mr                                 Leo  Zimmerman       1
#
#             age  Family_count  ticket  pclass  fare     embarked  survived
# 0     29.000000             0   24160       1   211  southampton         1
# 1      0.916700             3  113781       1   151  southampton         1
# 2      2.000000             3  113781       1   151  southampton         0
# 3     30.000000             3  113781       1   151  southampton         0
# 4     25.000000             3  113781       1   151  southampton         0
# ...         ...           ...     ...     ...   ...          ...       ...
# 1304  14.500000             1    2665       3    14    cherbourg         0
# 1305  29.881135             1    2665       3    14    cherbourg         0
# 1306  26.500000             0    2656       3     7    cherbourg         0
# 1307  27.000000             0    2670       3     7    cherbourg         0
# 1308  29.000000             0  315082       3     7  southampton         0
#
# [1309 rows x 11 columns]

# %%
Titanic['age'].max()
# Out:
# 80.0

# %%
Titanic['age']=pd.cut(Titanic['age'],bins=[0,15,30,59,100],labels=['Child','Teenager','Adult','Senior_Citizen'])
Titanic
# Out:
#         title                          first_name  last_name  gender  \
# 0        Miss                    Elisabeth Walton      Allen       0
# 1      Master                       Hudson Trevor    Allison       1
# 2        Miss                       Helen Loraine    Allison       0
# 3          Mr             Hudson Joshua Creighton    Allison       1
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)    Allison       0
# ...       ...                                 ...        ...     ...
# 1304     Miss                              Hileni     Zabour       0
# 1305     Miss                             Thamine     Zabour       0
# 1306       Mr                         Mapriededer   Zakarian       1
# 1307       Mr                               Ortin   Zakarian       1
# 1308       Mr                                 Leo  Zimmerman       1
#
#            age  Family_count  ticket  pclass  fare     embarked  survived
# 0     Teenager             0   24160       1   211  southampton         1
# 1        Child             3  113781       1   151  southampton         1
# 2        Child             3  113781       1   151  southampton         0
# 3     Teenager             3  113781       1   151  southampton         0
# 4     Teenager             3  113781       1   151  southampton         0
# ...        ...           ...     ...     ...   ...          ...       ...
# 1304     Child             1    2665       3    14    cherbourg         0
# 1305  Teenager             1    2665       3    14    cherbourg         0
# 1306  Teenager             0    2656       3     7    cherbourg         0
# 1307  Teenager             0    2670       3     7    cherbourg         0
# 1308  Teenager             0  315082       3     7  southampton         0
#
# [1309 rows x 11 columns]

# %%
Titanic.rename(columns={'age':'age_group'},inplace=True)
Titanic
# Out:
#         title                          first_name  last_name  gender  \
# 0        Miss                    Elisabeth Walton      Allen       0
# 1      Master                       Hudson Trevor    Allison       1
# 2        Miss                       Helen Loraine    Allison       0
# 3          Mr             Hudson Joshua Creighton    Allison       1
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)    Allison       0
# ...       ...                                 ...        ...     ...
# 1304     Miss                              Hileni     Zabour       0
# 1305     Miss                             Thamine     Zabour       0
# 1306       Mr                         Mapriededer   Zakarian       1
# 1307       Mr                               Ortin   Zakarian       1
# 1308       Mr                                 Leo  Zimmerman       1
#
#      age_group  Family_count  ticket  pclass  fare     embarked  survived
# 0     Teenager             0   24160       1   211  southampton         1
# 1        Child             3  113781       1   151  southampton         1
# 2        Child             3  113781       1   151  southampton         0
# 3     Teenager             3  113781       1   151  southampton         0
# 4     Teenager             3  113781       1   151  southampton         0
# ...        ...           ...     ...     ...   ...          ...       ...
# 1304     Child             1    2665       3    14    cherbourg         0
# 1305  Teenager             1    2665       3    14    cherbourg         0
# 1306  Teenager             0    2656       3     7    cherbourg         0
# 1307  Teenager             0    2670       3     7    cherbourg         0
# 1308  Teenager             0  315082       3     7  southampton         0
#
# [1309 rows x 11 columns]

# %% [markdown]
# Group by Records

# %%
gb_obj=Titanic.groupby('age_group')
# Out:
# <ipython-input-81-b8eb0d2585b3>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb_obj=Titanic.groupby('age_group')

# %%
gb_obj.groups
# Out:
# {'Child': [1, 2, 54, 55, 94, 193, 249, 273, 339, 340, 341, 350, 359, 377, 385, 398, 427, 430, 434, 478, 479, 492, 501, 513, 514, 515, 540, 541, 548, 549, 569, 582, 587, 588, 590, 591, 601, 611, 622, 623, 624, 627, 628, 639, 640, 641, 642, 643, 653, 657, 658, 659, 678, 679, 733, 734, 747, 762, 763, 792, 794, 807, 820, 825, 826, 827, 828, 830, 855, 866, 894, 895, 916, 934, 937, 1007, 1025, 1047, 1048, 1056, 1057, 1082, 1096, 1097, 1098, 1099, 1101, 1102, 1103, 1105, 1111, 1112, 1141, 1142, 1143, 1144, 1145, 1156, 1171, 1187, ...], 'Teenager': [0, 3, 4, 11, 12, 13, 15, 16, 22, 24, 25, 26, 27, 29, 32, 36, 37, 40, 46, 52, 53, 59, 64, 67, 69, 70, 71, 72, 73, 74, 80, 87, 90, 92, 97, 102, 106, 107, 108, 110, 111, 112, 113, 114, 117, 118, 121, 122, 125, 130, 132, 134, 137, 140, 143, 144, 147, 151, 152, 153, 157, 159, 166, 176, 179, 182, 184, 187, 189, 190, 191, 194, 195, 196, 197, 198, 199, 203, 204, 209, 214, 216, 219, 220, 222, 223, 225, 226, 227, 228, 229, 230, 235, 236, 237, 241, 250, 251, 254, 255, ...], 'Adult': [5, 7, 8, 10, 17, 18, 19, 20, 21, 23, 28, 30, 31, 33, 34, 35, 38, 39, 41, 42, 44, 45, 47, 48, 49, 50, 51, 56, 57, 58, 60, 62, 63, 65, 66, 68, 75, 76, 77, 79, 82, 84, 85, 86, 88, 89, 91, 93, 95, 96, 98, 99, 100, 101, 103, 104, 105, 109, 119, 120, 124, 126, 127, 128, 129, 131, 133, 136, 138, 139, 141, 142, 145, 146, 148, 149, 150, 154, 155, 156, 158, 160, 161, 162, 163, 164, 165, 167, 168, 169, 170, 171, 172, 173, 174, 175, 177, 178, 180, 181, ...], 'Senior_Citizen': [6, 9, 14, 43, 61, 78, 81, 83, 115, 116, 123, 135, 205, 217, 221, 252, 279, 284, 285, 286, 287, 300, 303, 304, 305, 321, 351, 432, 455, 456, 487, 506, 511, 594, 727, 782, 1068, 1225, 1235, 1261]}

# %%
gb_obj.get_group('Adult')
# Out:
#      title                           first_name     last_name  gender  \
# 5       Mr                                Harry      Anderson       1
# 7       Mr                            Thomas Jr       Andrews       1
# 8      Mrs       Edward Dale (Charlotte Lamson)      Appleton       0
# 10     Col                           John Jacob         Astor       1
# 17     Mrs   James (Helene DeLaudeniere Chaput)        Baxter       0
# ...    ...                                  ...           ...     ...
# 1286   Mrs   George Joseph (Shawneene Abi-Saab)        Whabee       0
# 1287    Mr                   Carl/Charles Peter      Widegren       1
# 1290   Mrs                  James (Ellen Needs)        Wilkes       0
# 1298    Mr                              Camille  Wittevrongel       1
# 1301    Mr                              Gerious       Youseff       1
#
#      age_group  Family_count    ticket  pclass  fare     embarked  survived
# 5        Adult             0     19952       1    26  southampton         1
# 7        Adult             0    112050       1     0  southampton         0
# 8        Adult             2     11769       1    51  southampton         1
# 10       Adult             1  PC 17757       1   227    cherbourg         0
# 17       Adult             1  PC 17558       1   247    cherbourg         1
# ...        ...           ...       ...     ...   ...          ...       ...
# 1286     Adult             0      2688       3     7    cherbourg         1
# 1287     Adult             0    347064       3     7  southampton         0
# 1290     Adult             1    363272       3     7  southampton         1
# 1298     Adult             0    345771       3     9  southampton         0
# 1301     Adult             0      2628       3     7    cherbourg         0
#
# [397 rows x 11 columns]

# %%
gb_obj.get_group('Child')
# Out:
#         title                  first_name     last_name  gender age_group  \
# 1      Master               Hudson Trevor       Allison       1     Child
# 2        Miss               Helen Loraine       Allison       0     Child
# 54     Master         William Thornton II        Carter       1     Child
# 55       Miss                 Lucile Polk        Carter       0     Child
# 94     Master                  Washington         Dodge       1     Child
# ...       ...                         ...           ...     ...       ...
# 1263   Master                 Walter John  van Billiard       1     Child
# 1265     Miss                   Catharina      Van Impe       0     Child
# 1279     Miss       Hulda Amanda Adolfina       Vestrom       0     Child
# 1300      Mrs   Antoni (Selini Alexander)       Yasbeck       0     Child
# 1304     Miss                      Hileni        Zabour       0     Child
#
#       Family_count    ticket  pclass  fare     embarked  survived
# 1                3    113781       1   151  southampton         1
# 2                3    113781       1   151  southampton         0
# 54               3    113760       1   120  southampton         1
# 55               3    113760       1   120  southampton         1
# 94               2     33638       1    81  southampton         1
# ...            ...       ...     ...   ...          ...       ...
# 1263             2  A/5. 851       3    14  southampton         0
# 1265             2    345773       3    24  southampton         0
# 1279             0    350406       3     7  southampton         0
# 1300             1      2659       3    14    cherbourg         1
# 1304             1      2665       3    14    cherbourg         0
#
# [115 rows x 11 columns]

# %%
gb=Titanic.groupby(['age_group','gender'])
# Out:
# <ipython-input-85-8c6a5740a9d5>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gb=Titanic.groupby(['age_group','gender'])

# %%
gb.get_group(('Adult',0))
# Out:
#       title                            first_name      last_name  gender  \
# 8       Mrs        Edward Dale (Charlotte Lamson)       Appleton       0
# 17      Mrs    James (Helene DeLaudeniere Chaput)         Baxter       0
# 18     Miss                                Albina        Bazzani       0
# 21      Mrs     Richard Leonard (Sallie Monypeny)       Beckwith       0
# 23     Miss                               Rosalie         Bidois       0
# ...     ...                                   ...            ...     ...
# 1158    Mrs            Viktor (Helena Wilhelmina)        Rosblom       0
# 1211    Mrs   William (Anna Bernhardina Karlsson)          Skoog       0
# 1276    Mrs   Julius (Emelia Maria Vandemoortele)  Vander Planke       0
# 1286    Mrs    George Joseph (Shawneene Abi-Saab)         Whabee       0
# 1290    Mrs                   James (Ellen Needs)         Wilkes       0
#
#      age_group  Family_count    ticket  pclass  fare     embarked  survived
# 8        Adult             2     11769       1    51  southampton         1
# 17       Adult             1  PC 17558       1   247    cherbourg         1
# 18       Adult             0     11813       1    76    cherbourg         1
# 21       Adult             2     11751       1    52  southampton         1
# 23       Adult             0  PC 17757       1   227    cherbourg         1
# ...        ...           ...       ...     ...   ...          ...       ...
# 1158     Adult             2    370129       3    20  southampton         0
# 1211     Adult             5    347088       3    27  southampton         0
# 1276     Adult             1    345763       3    18  southampton         0
# 1286     Adult             0      2688       3     7    cherbourg         1
# 1290     Adult             1    363272       3     7  southampton         1
#
# [142 rows x 11 columns]

# %% [markdown]
# Aggregate Methods

# %%
Titanic.count()
# Out:
# title           1309
# first_name      1309
# last_name       1309
# gender          1309
# age_group       1309
# Family_count    1309
# ticket          1309
# pclass          1309
# fare            1309
# embarked        1309
# survived        1309
# dtype: int64

# %%
Titanic['embarked'].count()
# Out:
# np.int64(1309)

# %%
gp_obj=Titanic.groupby('embarked')
gp_obj.count()
# Out:
#              title  first_name  last_name  gender  age_group  Family_count  \
# embarked
# cherbourg      270         270        270     270        270           270
# qeenstown      123         123        123     123        123           123
# southampton    916         916        916     916        916           916
#
#              ticket  pclass  fare  survived
# embarked
# cherbourg       270     270   270       270
# qeenstown       123     123   123       123
# southampton     916     916   916       916

# %%
gp_obj['age_group'].count()
# Out:
# embarked
# cherbourg      270
# qeenstown      123
# southampton    916
# Name: age_group, dtype: int64

# %%
gp_obj[['age_group','survived']].count()
# Out:
#              age_group  survived
# embarked
# cherbourg          270       270
# qeenstown          123       123
# southampton        916       916

# %% [markdown]
# max()

# %%
Titanic['fare'].max()
# Out:
# 512

# %%
gp_obj.max()
# Out:
#                      title                           first_name  \
# embarked
# cherbourg              Sir                             Yousseff
# qeenstown              Rev    William Edward (Lillian E Thorpe)
# southampton   the Countess   of (Lucy Noel Martha Dyer-Edwards)
#
#                  last_name  gender       age_group  Family_count  \
# embarked
# cherbourg        del Carlo       1  Senior_Citizen             4
# qeenstown            Tobin       1  Senior_Citizen             5
# southampton  van Melkebeke       1  Senior_Citizen            10
#
#                     ticket  pclass  fare  survived
# embarked
# cherbourg    SC/Paris 2163       3   512         1
# qeenstown        AQ/4 3130       3    90         1
# southampton      WE/P 5735       3   263         1

# %%
gp_obj[['fare','age_group']].max()
# Out:
#              fare       age_group
# embarked
# cherbourg     512  Senior_Citizen
# qeenstown      90  Senior_Citizen
# southampton   263  Senior_Citizen

# %% [markdown]
# min()

# %%
Titanic['fare'].min()
# Out:
# 0

# %%
gp_obj['fare'].min()
# Out:
# embarked
# cherbourg      4
# qeenstown      6
# southampton    0
# Name: fare, dtype: int64

# %%
gp_obj[['fare','age_group']].min()
# Out:
#              fare age_group
# embarked
# cherbourg       4     Child
# qeenstown       6     Child
# southampton     0     Child

# %%
gp_obj['fare'].sum()
# Out:
# embarked
# cherbourg      16714
# qeenstown       1449
# southampton    24863
# Name: fare, dtype: int64

# %%
gp_obj.sum(numeric_only=True)
# Out:
#              gender  Family_count  pclass   fare  survived
# embarked
# cherbourg       157           208     500  16714       150
# qeenstown        63            56     356   1449        44
# southampton     623           893    2148  24863       306

# %%
Titanic.sum(numeric_only=True)
# Out:
# gender            843
# Family_count     1157
# pclass           3004
# fare            43026
# survived          500
# dtype: int64

# %%
Titanic['fare'].mean()
# Out:
# np.float64(32.86936592818946)

# %%
# 1. get the statistical description for all numerical columns
Titanic.describe()
# Out:
#             gender  Family_count       pclass         fare     survived
# count  1309.000000   1309.000000  1309.000000  1309.000000  1309.000000
# mean      0.644003      0.883881     2.294882    32.869366     0.381971
# std       0.478997      1.583639     0.837836    51.747244     0.486055
# min       0.000000      0.000000     1.000000     0.000000     0.000000
# 25%       0.000000      0.000000     2.000000     7.000000     0.000000
# 50%       1.000000      0.000000     3.000000    14.000000     0.000000
# 75%       1.000000      1.000000     3.000000    31.000000     1.000000
# max       1.000000     10.000000     3.000000   512.000000     1.000000

# %%
# 2. get top 5 records(passangers data)
Titanic.head(n=5)
# Out:
#      title                          first_name last_name  gender age_group  \
# 0     Miss                    Elisabeth Walton     Allen       0  Teenager
# 1   Master                       Hudson Trevor   Allison       1     Child
# 2     Miss                       Helen Loraine   Allison       0     Child
# 3       Mr             Hudson Joshua Creighton   Allison       1  Teenager
# 4      Mrs   Hudson J C (Bessie Waldo Daniels)   Allison       0  Teenager
#
#    Family_count  ticket  pclass  fare     embarked  survived
# 0             0   24160       1   211  southampton         1
# 1             3  113781       1   151  southampton         1
# 2             3  113781       1   151  southampton         0
# 3             3  113781       1   151  southampton         0
# 4             3  113781       1   151  southampton         0

# %%
# 3. get the last 5 records
Titanic.tail(n=5)
# Out:
#       title    first_name  last_name  gender age_group  Family_count  ticket  \
# 1304   Miss        Hileni     Zabour       0     Child             1    2665
# 1305   Miss       Thamine     Zabour       0  Teenager             1    2665
# 1306     Mr   Mapriededer   Zakarian       1  Teenager             0    2656
# 1307     Mr         Ortin   Zakarian       1  Teenager             0    2670
# 1308     Mr           Leo  Zimmerman       1  Teenager             0  315082
#
#       pclass  fare     embarked  survived
# 1304       3    14    cherbourg         0
# 1305       3    14    cherbourg         0
# 1306       3     7    cherbourg         0
# 1307       3     7    cherbourg         0
# 1308       3     7  southampton         0

# %%
# 4. get the total_no_records
len(Titanic)
Titanic.shape[0]
# Out:
# 1309

# %%
# 5. get the total columns
print(Titanic.columns)
Titanic.shape[1]
# Out:
# Index(['title', 'first_name', 'last_name', 'gender', 'age_group',
#        'Family_count', 'ticket', 'pclass', 'fare', 'embarked', 'survived'],
#       dtype='object')
# 11

# %%
# 6. get the first row
Titanic.head(1)
Titanic.loc[0,::]
# it will show all the records from first row
# index value is always start with 0
# Out:
# title                        Miss
# first_name       Elisabeth Walton
# last_name                   Allen
# gender                          0
# age_group                Teenager
# Family_count                    0
# ticket                      24160
# pclass                          1
# fare                          211
# embarked              southampton
# survived                        1
# Name: 0, dtype: object

# %%
# 7. get the second row
Titanic.loc[1,::]
# Out:
# title                   Master
# first_name       Hudson Trevor
# last_name              Allison
# gender                       1
# age_group                Child
# Family_count                 3
# ticket                  113781
# pclass                       1
# fare                       151
# embarked           southampton
# survived                     1
# Name: 1, dtype: object

# %%
# 8. get the fname and age of the all the passangers
Titanic.loc[::,['first_name','age_group']]
# Out:
#                               first_name age_group
# 0                       Elisabeth Walton  Teenager
# 1                          Hudson Trevor     Child
# 2                          Helen Loraine     Child
# 3                Hudson Joshua Creighton  Teenager
# 4      Hudson J C (Bessie Waldo Daniels)  Teenager
# ...                                  ...       ...
# 1304                              Hileni     Child
# 1305                             Thamine  Teenager
# 1306                         Mapriededer  Teenager
# 1307                               Ortin  Teenager
# 1308                                 Leo  Teenager
#
# [1309 rows x 2 columns]

# %%
# 9. get the 5th and 6th passangers fname,age and survived details
Titanic.loc[[5,6],['first_name','age_group','survived']]
# Out:
#             first_name       age_group  survived
# 5                Harry           Adult         1
# 6   Kornelia Theodosia  Senior_Citizen         1

# %%
# 10. get the passengers details of pclass 1
cond=Titanic['pclass']==1
Titanic[cond]
# Out:
#        title                          first_name         last_name  gender  \
# 0       Miss                    Elisabeth Walton             Allen       0
# 1     Master                       Hudson Trevor           Allison       1
# 2       Miss                       Helen Loraine           Allison       0
# 3         Mr             Hudson Joshua Creighton           Allison       1
# 4        Mrs   Hudson J C (Bessie Waldo Daniels)           Allison       0
# ..       ...                                 ...               ...     ...
# 318       Mr                    Fletcher Fellows  Williams-Lambert       1
# 319     Miss                         Helen Alice            Wilson       0
# 320       Mr                                Hugh           Woolner       1
# 321       Mr                              George            Wright       1
# 322     Miss                         Marie Grice             Young       0
#
#           age_group  Family_count    ticket  pclass  fare     embarked  \
# 0          Teenager             0     24160       1   211  southampton
# 1             Child             3    113781       1   151  southampton
# 2             Child             3    113781       1   151  southampton
# 3          Teenager             3    113781       1   151  southampton
# 4          Teenager             3    113781       1   151  southampton
# ..              ...           ...       ...     ...   ...          ...
# 318        Teenager             0    113510       1    35  southampton
# 319           Adult             0     16966       1   134    cherbourg
# 320        Teenager             0     19947       1    35  southampton
# 321  Senior_Citizen             0    113807       1    26  southampton
# 322           Adult             0  PC 17760       1   135    cherbourg
#
#      survived
# 0           1
# 1           1
# 2           0
# 3           0
# 4           0
# ..        ...
# 318         0
# 319         1
# 320         1
# 321         0
# 322         1
#
# [323 rows x 11 columns]

# %%
# 11. get the passengers fname and age of pclass 1
cond=Titanic['pclass']==1
Titanic.loc[cond,['first_name','age_group']]
# Out:
#                              first_name       age_group
# 0                      Elisabeth Walton        Teenager
# 1                         Hudson Trevor           Child
# 2                         Helen Loraine           Child
# 3               Hudson Joshua Creighton        Teenager
# 4     Hudson J C (Bessie Waldo Daniels)        Teenager
# ..                                  ...             ...
# 318                    Fletcher Fellows        Teenager
# 319                         Helen Alice           Adult
# 320                                Hugh        Teenager
# 321                              George  Senior_Citizen
# 322                         Marie Grice           Adult
#
# [323 rows x 2 columns]

# %%
# 12. get the male passangers details of pclass 1
cond1=(Titanic['gender']==1)&(Titanic['pclass']==1)
Titanic.loc[cond1,::]
# Out:
#        title                first_name         last_name  gender  \
# 1     Master             Hudson Trevor           Allison       1
# 3         Mr   Hudson Joshua Creighton           Allison       1
# 5         Mr                     Harry          Anderson       1
# 7         Mr                 Thomas Jr           Andrews       1
# 9         Mr                     Ramon      Artagaveytia       1
# ..       ...                       ...               ...     ...
# 316       Mr             Charles Duane          Williams       1
# 317       Mr         Richard Norris II          Williams       1
# 318       Mr          Fletcher Fellows  Williams-Lambert       1
# 320       Mr                      Hugh           Woolner       1
# 321       Mr                    George            Wright       1
#
#           age_group  Family_count    ticket  pclass  fare     embarked  \
# 1             Child             3    113781       1   151  southampton
# 3          Teenager             3    113781       1   151  southampton
# 5             Adult             0     19952       1    26  southampton
# 7             Adult             0    112050       1     0  southampton
# 9    Senior_Citizen             0  PC 17609       1    49    cherbourg
# ..              ...           ...       ...     ...   ...          ...
# 316           Adult             1  PC 17597       1    61    cherbourg
# 317        Teenager             1  PC 17597       1    61    cherbourg
# 318        Teenager             0    113510       1    35  southampton
# 320        Teenager             0     19947       1    35  southampton
# 321  Senior_Citizen             0    113807       1    26  southampton
#
#      survived
# 1           1
# 3           0
# 5           1
# 7           0
# 9           0
# ..        ...
# 316         0
# 317         1
# 318         0
# 320         1
# 321         0
#
# [179 rows x 11 columns]

# %%
# 13. get the female passengers fname who were survived in pclass 1
cond=(Titanic['gender']==1)&(Titanic['survived']==1)&(Titanic['pclass']==1)
Titanic.loc[cond,['first_name']]
# Out:
#                  first_name
# 1             Hudson Trevor
# 5                     Harry
# 14    Algernon Henry Wilson
# 20          Richard Leonard
# 22              Karl Howell
# ..                      ...
# 292            Elmer Zebley
# 295         John Borland Jr
# 298     Gilbert Milligan Jr
# 317       Richard Norris II
# 320                    Hugh
#
# [61 rows x 1 columns]

# %%
# 14. get the passengers detailes whose embarked is southampton,cherbourg
cond=(Titanic['embarked']=='southampton')|(Titanic['embarked']=='cherbourg')
Titanic.loc[cond,::]
# or use this to reduce the code
# Titanic[Titanic['embarked'].isin(['southampton','cherbourg'])]
# Out:
#         title                          first_name  last_name  gender  \
# 0        Miss                    Elisabeth Walton      Allen       0
# 1      Master                       Hudson Trevor    Allison       1
# 2        Miss                       Helen Loraine    Allison       0
# 3          Mr             Hudson Joshua Creighton    Allison       1
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)    Allison       0
# ...       ...                                 ...        ...     ...
# 1304     Miss                              Hileni     Zabour       0
# 1305     Miss                             Thamine     Zabour       0
# 1306       Mr                         Mapriededer   Zakarian       1
# 1307       Mr                               Ortin   Zakarian       1
# 1308       Mr                                 Leo  Zimmerman       1
#
#      age_group  Family_count  ticket  pclass  fare     embarked  survived
# 0     Teenager             0   24160       1   211  southampton         1
# 1        Child             3  113781       1   151  southampton         1
# 2        Child             3  113781       1   151  southampton         0
# 3     Teenager             3  113781       1   151  southampton         0
# 4     Teenager             3  113781       1   151  southampton         0
# ...        ...           ...     ...     ...   ...          ...       ...
# 1304     Child             1    2665       3    14    cherbourg         0
# 1305  Teenager             1    2665       3    14    cherbourg         0
# 1306  Teenager             0    2656       3     7    cherbourg         0
# 1307  Teenager             0    2670       3     7    cherbourg         0
# 1308  Teenager             0  315082       3     7  southampton         0
#
# [1186 rows x 11 columns]

# %%
# 15. get the no_of_passengers
Titanic.shape[0]
# Out:
# 1309

# %%
# 16. get the no_of_male passengers
Titanic[Titanic['gender']==1].shape[0]
# Out:
# 843

# %%
# 17. get the highest fare
Titanic['fare'].max()
# Out:
# 512

# %%
# 18. get the lowest fare among female passenge
Titanic[Titanic['gender']==1]['fare'].min()
# Out:
# 0

# %%
# 19. get the no_of survival
Titanic[Titanic['survived']==1].shape[0]
# Out:
# 500

# %%
# 20. get the survival rate
Titanic[Titanic['survived']==1].shape[0]/Titanic.shape[0]*100
# Out:
# 38.19709702062643

# %%
# 21. get the aggregates for fare column
Titanic['fare'].agg(['min','max','mean','median','std','var'])
# Out:
# min          0.000000
# max        512.000000
# mean        32.869366
# median      14.000000
# std         51.747244
# var       2677.777264
# Name: fare, dtype: float64

# %%
# 22. get the no_of_passengers in each gender
Titanic['gender'].value_counts()
# Out:
# gender
# 1    843
# 0    466
# Name: count, dtype: int64

# %%
# 23. get the total fare in each pclass
Titanic.groupby('pclass')['fare'].sum()
# Out:
# pclass
# 1    28129
# 2     5806
# 3     9091
# Name: fare, dtype: int64

# %%
# 24. get the pclass wise survived rate and count
Titanic.groupby('pclass')['survived'].value_counts()
# Titanic.groupby('pclass')['survived'].value_counts(normalize=True)*100
# Out:
# pclass  survived
# 1       1           200
#         0           123
# 2       0           158
#         1           119
# 3       0           528
#         1           181
# Name: count, dtype: int64

# %%
# 25. get the pclass,gender wise survival rate
Titanic.groupby(['pclass','gender'])['survived'].value_counts()
# Titanic.groupby(['pclass','gender'])['survived'].value_counts(normalize=True)*100
# Out:
# pclass  gender  survived
# 1       0       1           139
#                 0             5
#         1       0           118
#                 1            61
# 2       0       1            94
#                 0            12
#         1       0           146
#                 1            25
# 3       0       0           110
#                 1           106
#         1       0           418
#                 1            75
# Name: count, dtype: int64

# %%
# 26. get the no_of_passengers in each pclass
Titanic['pclass'].value_counts()
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
# 27. find the pclass in which lowest no_of passengers are there
Titanic['pclass'].value_counts().idxmin()
# Out:
# np.int64(2)

# %%
# 28. find the no_of_families travelling
Titanic['Family_count'].value_counts()
# Out:
# Family_count
# 0     790
# 1     235
# 2     159
# 3      43
# 5      25
# 4      22
# 6      16
# 10     11
# 7       8
# Name: count, dtype: int64

# %%
# 29. no_of_families travelling who got survived
Titanic[Titanic['survived']==1]['Family_count'].value_counts()
# Out:
# Family_count
# 0    239
# 1    126
# 2     90
# 3     30
# 4      6
# 5      5
# 6      4
# Name: count, dtype: int64

# %%
# 30.what is the correlation between fare and pclass
Titanic[['fare','pclass']].corr()
# Out:
#             fare    pclass
# fare    1.000000 -0.559443
# pclass -0.559443  1.000000

# %%
# 31.what is the correlation between fare and survived?
Titanic[['fare','survived']].corr()
# Out:
#               fare  survived
# fare      1.000000  0.244274
# survived  0.244274  1.000000

# %%
# 33. what is the correlation between gender and survived?
Titanic[['gender','survived']].corr()
# Out:
#             gender  survived
# gender    1.000000 -0.528693
# survived -0.528693  1.000000

# %%
# 34.get the pclass wise male and female count and survived
Titanic.groupby(['pclass','gender'])['survived'].value_counts()
# Out:
# pclass  gender  survived
# 1       0       1           139
#                 0             5
#         1       0           118
#                 1            61
# 2       0       1            94
#                 0            12
#         1       0           146
#                 1            25
# 3       0       0           110
#                 1           106
#         1       0           418
#                 1            75
# Name: count, dtype: int64

# %%
# 35.get the age_seg wise no_of_passangers and survival rate
Titanic.groupby('age_group')['survived'].value_counts()
# Out:
# <ipython-input-135-ebc39bb11c66>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Titanic.groupby('age_group')['survived'].value_counts()
# age_group       survived
# Child           1            66
#                 0            49
# Teenager        0           502
#                 1           255
# Adult           0           230
#                 1           167
# Senior_Citizen  0            28
#                 1            12
# Name: count, dtype: int64

# %%
Titanic.groupby('age_group')['survived'].idxmax()
# Out:
# <ipython-input-136-58c8dc9b2d1e>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Titanic.groupby('age_group')['survived'].idxmax()
# age_group
# Child             1
# Teenager          0
# Adult             5
# Senior_Citizen    6
# Name: survived, dtype: int64

# %%
# 35. get the age_seg which has high survival rate
Titanic.groupby('age_group')['survived'].value_counts().idxmax()
# Out:
# <ipython-input-137-df3cb70df1c9>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Titanic.groupby('age_group')['survived'].value_counts().idxmax()
# ('Teenager', np.int64(0))

# %%
# 36. get the gender and age which has high survival rate
Titanic.groupby(['gender','age_group'])['survived'].value_counts().idxmax()
# Out:
# <ipython-input-138-eef9eefbdc0a>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Titanic.groupby(['gender','age_group'])['survived'].value_counts().idxmax()
# (np.int64(1), 'Teenager', np.int64(0))

# %%
# 37. get the pclass,gender,age in which survival rate high
Titanic.groupby(['pclass','gender','age_group'])['survived'].value_counts().idxmax()
# Out:
# <ipython-input-139-7f6df10630e1>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Titanic.groupby(['pclass','gender','age_group'])['survived'].value_counts().idxmax()
# (np.int64(3), np.int64(1), 'Teenager', np.int64(0))

# %%
# 38. get the solo travelers full name
Titanic[Titanic['Family_count']==0]['first_name']
# Out:
# 0        Elisabeth Walton
# 5                   Harry
# 7               Thomas Jr
# 9                   Ramon
# 12       Leontine Pauline
#               ...
# 1302                Wazli
# 1303              Gerious
# 1306          Mapriededer
# 1307                Ortin
# 1308                  Leo
# Name: first_name, Length: 790, dtype: object

# %%
# 39.solo travelers survival rate v/s passengers with family survival rate
Titanic.groupby('Family_count')['survived'].value_counts()
# Out:
# Family_count  survived
# 0             0           551
#               1           239
# 1             1           126
#               0           109
# 2             1            90
#               0            69
# 3             1            30
#               0            13
# 4             0            16
#               1             6
# 5             0            20
#               1             5
# 6             0            12
#               1             4
# 7             0             8
# 10            0            11
# Name: count, dtype: int64

# %%
#  Find the gender and pclass wise survival rate of solo travelers
Titanic[Titanic['Family_count']==0].groupby(['gender','pclass'])['survived'].value_counts()
# Out:
# gender  pclass  survived
# 0       1       1            50
#                 0             2
#         2       1            36
#                 0             6
#         3       1            56
#                 0            44
# 1       1       0            76
#                 1            32
#         2       0           104
#                 1            12
#         3       0           319
#                 1            53
# Name: count, dtype: int64

# %%
 import seaborn as sns
 import matplotlib.pyplot as plt

# %%
Titanic['gender']=Titanic['gender'].replace({1:'male',0:'female'})
Titanic
# Out:
#         title                          first_name  last_name  gender  \
# 0        Miss                    Elisabeth Walton      Allen  female
# 1      Master                       Hudson Trevor    Allison    male
# 2        Miss                       Helen Loraine    Allison  female
# 3          Mr             Hudson Joshua Creighton    Allison    male
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)    Allison  female
# ...       ...                                 ...        ...     ...
# 1304     Miss                              Hileni     Zabour  female
# 1305     Miss                             Thamine     Zabour  female
# 1306       Mr                         Mapriededer   Zakarian    male
# 1307       Mr                               Ortin   Zakarian    male
# 1308       Mr                                 Leo  Zimmerman    male
#
#      age_group  Family_count  ticket  pclass  fare     embarked  survived
# 0     Teenager             0   24160       1   211  southampton         1
# 1        Child             3  113781       1   151  southampton         1
# 2        Child             3  113781       1   151  southampton         0
# 3     Teenager             3  113781       1   151  southampton         0
# 4     Teenager             3  113781       1   151  southampton         0
# ...        ...           ...     ...     ...   ...          ...       ...
# 1304     Child             1    2665       3    14    cherbourg         0
# 1305  Teenager             1    2665       3    14    cherbourg         0
# 1306  Teenager             0    2656       3     7    cherbourg         0
# 1307  Teenager             0    2670       3     7    cherbourg         0
# 1308  Teenager             0  315082       3     7  southampton         0
#
# [1309 rows x 11 columns]

# %%
# 1. plot the total count of male and female passengers
a=sns.histplot(x='gender',data=Titanic)
a.bar_label(a.containers[0])
plt.title('Gender Count')

# observation--> male passengers are more than female passnagers in titanic data set
# Out:
# Text(0.5, 1.0, 'Gender Count')

# %%
# 2. plot the total count of male and female passengers in each passangers pclass
a=sns.countplot(data=Titanic,x='gender',hue='pclass')
for c in a.containers:
  a.bar_label(c)

# Observation--> male and female passengers are more in pclass 3 and less in pclass 2

# %%
# 3.plot the count of passengers in each age catogories
age_group = Titanic['age_group'].value_counts()
plt.pie(x=age_group.values,labels=age_group.index,autopct='%.3f%%',explode=[0,0,0.05,0])

# Observation--> In this Titani Dataset Teenagers are Travelled more than other age group
# Out:
# ([<matplotlib.patches.Wedge at 0x7c31d3524190>,
#   <matplotlib.patches.Wedge at 0x7c32202a4110>,
#   <matplotlib.patches.Wedge at 0x7c32202a5850>,
#   <matplotlib.patches.Wedge at 0x7c32202a5010>],
#  [Text(-0.267878440406581, 1.066883846145089, 'Teenager'),
#   Text(-0.13823346329618577, -1.0912797577272029, 'Adult'),
#   Text(1.0263437376609925, -0.5187663560448617, 'Child'),
#   Text(1.0949351398417504, -0.10543737259495185, 'Senior_Citizen')],
#  [Text(-0.14611551294904415, 0.5819366433518667, '57.830%'),
#   Text(-0.0754000708888286, -0.5952435042148378, '30.328%'),
#   Text(0.5801073299823001, -0.2932157664601392, '8.785%'),
#   Text(0.597237349004591, -0.057511294142701, '3.056%')])

# %%
# 4. plot the gender wise count of survived and not_survived passengers

plt.figure(figsize=(6,4))
a=sns.countplot(data=Titanic,x='survived',hue='gender')
for c in a.containers:
  a.bar_label(c)
plt.xticks([0,1],labels=['non_survived','survived'])
# Out:
# ([<matplotlib.axis.XTick at 0x7c31d0ec9310>,
#   <matplotlib.axis.XTick at 0x7c32202750d0>],
#  [Text(0, 0, 'non_survived'), Text(1, 0, 'survived')])

# %%
# 5. plot the variation in fare and age
plt.figure(figsize=(6,4))
a=sns.scatterplot(data=Titanic,x='age_group',y='fare')

# Observation--> In this charts adult paying high fare

# %%
# 6.Plot the count of survived and non-survived passengers in each age category.
plt.figure(figsize=(6,3))
a=sns.countplot(data=Titanic,x='survived',hue='age_group')
for c in a.containers:
  a.bar_label(c)
plt.xticks([0,1],labels=['non_survived','survived'])
# questions:
# adults are more in which pclass
# adults are more in which  gender
# Out:
# ([<matplotlib.axis.XTick at 0x7c31d0f99950>,
#   <matplotlib.axis.XTick at 0x7c3220251b90>],
#  [Text(0, 0, 'non_survived'), Text(1, 0, 'survived')])

# %%
# 7.Plot the total fare collected for each passenger class.
# plt.figure(figsize=(6,3))
# a=sns.barplot(data=Titanic,x='pclass',y='fare',estimator='sum')
# a.bar_label(a.containers[0],)

# Observation--> In this Charts pclass 1 passengers are paid high fare amount

# Calculate the total fare for each passenger class
total_fare = Titanic.groupby('pclass')['fare'].sum()

# Create the bar plot
plt.figure(figsize=(6, 3))
ax = sns.barplot(x=total_fare.index, y=total_fare.values)
plt.xlabel("Passenger Class")
plt.ylabel("Total Fare")
plt.title("Total Fare Collected for Each Passenger Class")

# Add labels to the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.show()

# %%
# 8.Plot the distribution of fares.
plt.figure(figsize=(6,5))
a=sns.kdeplot(data=Titanic,x='fare',hue='gender',fill=True,shade=True)
a.grid()
plt.xticks(np.arange(0,600,50))
# in 10 to 80 male passengers are 1.6 density and 0 to 50 female are have more density
# Out:
# <ipython-input-153-6995ba2c7864>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   a=sns.kdeplot(data=Titanic,x='fare',hue='gender',fill=True,shade=True)
# ([<matplotlib.axis.XTick at 0x7c31d0e7fa10>,
#   <matplotlib.axis.XTick at 0x7c31d0fa1950>,
#   <matplotlib.axis.XTick at 0x7c31d0d0df10>,
#   <matplotlib.axis.XTick at 0x7c31d0d3b490>,
#   <matplotlib.axis.XTick at 0x7c31d0cb27d0>,
#   <matplotlib.axis.XTick at 0x7c31d0d42d10>,
#   <matplotlib.axis.XTick at 0x7c31d0d44f90>,
#   <matplotlib.axis.XTick at 0x7c31d0d47510>,
#   <matplotlib.axis.XTick at 0x7c31d0e200d0>,
#   <matplotlib.axis.XTick at 0x7c31d0d79550>,
#   <matplotlib.axis.XTick at 0x7c31d0d7b890>,
#   <matplotlib.axis.XTick at 0x7c31d0d71d90>],
#  [Text(0, 0, '0'),
#   Text(50, 0, '50'),
#   Text(100, 0, '100'),
#   Text(150, 0, '150'),
#   Text(200, 0, '200'),
#   Text(250, 0, '250'),
#   Text(300, 0, '300'),
#   Text(350, 0, '350'),
#   Text(400, 0, '400'),
#   Text(450, 0, '450'),
#   Text(500, 0, '500'),
#   Text(550, 0, '550')])

# %%
# 9. plot the distribution of ages.
plt.figure(figsize=(6,4))
a=sns.histplot(data=Titanic,x='age_group')
a.bar_label(a.containers[0])
# Out:
# [Text(0, 0, '115'), Text(0, 0, '757'), Text(0, 0, '397'), Text(0, 0, '40')]

# %%
# 10.Plot the relationship between fare and passenger class.
plt.figure(figsize=(6,3))
a=sns.lineplot(data=Titanic,x='pclass',y='fare')
a.grid()
# we have outlier which is avove 500
# p class is discrid data placss is increasing and fare will be decreasing
